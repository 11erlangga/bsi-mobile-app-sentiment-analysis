# %% [markdown]
# # Import Dependencies

# %% [markdown]
# Pada tahap ini dilakukan instalasi pustaka (*library*) yang diperlukan untuk menjalankan proses analisis dan pemodelan **Natural Language Processing (NLP)**. Library `gensim` digunakan untuk membangun model **FastText**, yaitu metode *word embedding* yang merepresentasikan kata dalam bentuk vektor numerik sehingga dapat menangkap hubungan semantik antar kata. Selain itu, library `scikit-optimize` digunakan untuk melakukan optimasi hiperparameter model melalui pendekatan *Bayesian Optimization*.

# %%
# !pip install gensim scikit-optimize
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.12/dist-packages (0.10.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.5.3)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (26.2.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (2.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.6.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (26.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.6.0)

# %% [markdown]
# Nilai *random seed* ditetapkan untuk memastikan proses eksperimen bersifat ***reproducible***, sehingga hasil pelatihan model dapat direproduksi kembali ketika kode dijalankan ulang. Parameter `VECTOR_SIZE` digunakan untuk menentukan dimensi vektor pada model **FastText**.

# %%
SEED = 1010
VECTOR_SIZE = 100

# %%
import joblib
import nltk
import numpy as np
import pandas as pd
import plotly.express as px
import tensorflow as tf
from gensim.models import FastText
from lightgbm import LGBMClassifier
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC
from skopt import BayesSearchCV
from skopt.space import Categorical, Integer, Real
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, Input
from tensorflow.keras.models import Sequential
from umap import UMAP

# custom module
from utils import model_eval, plot_history, sentence_vector

nltk.download("punkt_tab")

tf.random.set_seed(SEED)
np.random.seed(SEED)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# # Load Data

# %% [markdown]
# Dataset dimuat menggunakan fungsi `read_csv()` dari pustaka `pandas`. Dari dataset yang tersedia, hanya dua kolom yang digunakan dalam penelitian ini, yaitu kolom `content` yang berisi teks ulasan pengguna dan kolom `sentiment` yang berisi label sentimen.

# %%
# Memuat dataset
df = pd.read_csv("clean_review_bsi_mobile.csv")
df = df[['content', 'sentiment']]
df.sample(10, random_state=SEED)
# Out:
#                                                  content sentiment
# 6393   transaksi susah ribet transfer orangkirain gag...  negative
# 823                                      top up dana gk   negative
# 12199                 force close melulu qr eror mlu deh  negative
# 2259   paksa ganti akses uang situ suruh ganti pakai ...  negative
# 3632                                          mudah guna  positive
# 9423   apknya ui banget pakai syariah capek banget ba...  negative
# 13536  pakai kendalasemua bagus profil layan pinjaman...  positive
# 8017   baru deteksi device rooted device gx rooted al...  negative
# 13047                                             ganggu  negative
# 3501                                          buka habis  negative

# %%
# Tampilkan informasi umum tentang dataset
print("\nInformasi dataset:")
df.info()
# Out:
# Informasi dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13969 entries, 0 to 13968
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   content    13963 non-null  object
#  1   sentiment  13969 non-null  object
# dtypes: object(2)
# memory usage: 218.4+ KB

# %% [markdown]
# Berdasarkan informasi dataset, terdapat **13.969 baris data** dengan dua atribut utama, yaitu teks ulasan (`content`) dan label sentimen (`sentiment`).

# %%
# Cek missing values
print("\nMissing values per fitur:")
print(df.isnull().sum())
# Out:
# Missing values per fitur:
# content      6
# sentiment    0
# dtype: int64

# %% [markdown]
# Selanjutnya dilakukan pemeriksaan terhadap *missing values* pada setiap fitur. Hasil pemeriksaan menunjukkan terdapat **6 nilai kosong pada kolom `content`**. Data yang memiliki nilai kosong kemudian dihapus menggunakan metode `dropna()` untuk menjaga kualitas data yang digunakan dalam proses pelatihan model.

# %%
# Menghapus baris dengan missing values
df.dropna(inplace=True)

print("\nInformasi dataset setelah penanganan missing values:")
df.info()
# Out:
# Informasi dataset setelah penanganan missing values:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13963 entries, 0 to 13968
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   content    13963 non-null  object
#  1   sentiment  13963 non-null  object
# dtypes: object(2)
# memory usage: 327.3+ KB

# %% [markdown]
# Setelah proses penanganan *missing values*, jumlah data yang tersisa adalah **13.963 baris** yang selanjutnya digunakan dalam proses pemodelan.

# %% [markdown]
# # Data Splitting

# %%
# Memisahkan fitur dengan label
X = df['content']
y = df['sentiment']

# %%
# Bagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=SEED)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11170,), (2793,), (11170,), (2793,))

# %% [markdown]
# Data kemudian dibagi menjadi data latih dan data uji menggunakan teknik *stratified train-test split* berdasarkan label `sentiment` dengan proporsi **80% data latih dan 20% data uji**. Pendekatan ini digunakan untuk memastikan distribusi kelas sentimen pada data latih dan data uji tetap seimbang dengan distribusi pada dataset asli.

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ## Tokenization

# %% [markdown]
# Pada tahap ini dilakukan **tokenisasi** terhadap teks pada kolom `content` menggunakan fungsi `word_tokenize()` dari pustaka `nltk`. Proses tokenisasi bertujuan untuk memecah teks ulasan menjadi unit kata (*tokens*) sehingga dapat diproses oleh model FastText dalam tahap pembelajaran representasi kata.

# %%
# Melakukan tokenisasi terhadap kolom `content`
X_train, X_test = X_train.apply(word_tokenize), X_test.apply(word_tokenize)

X_train.sample(10, random_state=SEED)
# Out:
# 12502                             [murah, kualitas, murah]
# 7493                                              [mantap]
# 5069     [alhamdulillah, transaksi, mudah, cocok, anti,...
# 5763                                              [mantap]
# 11172    [guna, m-banking, bni, syariah, trus, ganti, t...
# 8736       [halo, upload, update, versi, baru, appgallery]
# 7795     [rooted, device, hp, emak, emak, pakai, wa, yu...
# 3919     [buka, baru, coba, hapus, instal, tetep, buka,...
# 7158                                               [bagus]
# 9895     [aktivasi, susah, capek, goyang, kepala, gagal...
# Name: content, dtype: object

# %% [markdown]
# ## FastText

# %% [markdown]
# Setelah proses tokenisasi, dilakukan pelatihan model **FastText** untuk menghasilkan representasi vektor dari setiap kata. Model FastText mempelajari hubungan semantik antar kata berdasarkan konteks kemunculannya dalam kalimat.
#
# Pada penelitian ini digunakan beberapa parameter utama, yaitu:
#
# * `vector_size = 100` untuk menentukan dimensi vektor kata
#
# * `window = 10` untuk menentukan jumlah kata konteks yang diperhatikan di sekitar kata target
#
# * `min_count = 5` untuk mengabaikan kata yang muncul kurang dari 5 kali
#
# * `epochs = 100` untuk jumlah iterasi pelatihan model

# %%
# Melatih model FastText untuk mempelajari representasi vektor kata
embed_model = FastText(
    sentences=X_train,
    vector_size=VECTOR_SIZE,
    window=10,
    min_count=5,
    workers=4,
    epochs=100,
    seed=SEED
)

# %% [markdown]
# Setelah model FastText dilatih, langkah selanjutnya adalah melakukan **ekstraksi fitur kalimat**. Setiap kalimat direpresentasikan dalam bentuk vektor dengan cara menggabungkan vektor kata yang terdapat dalam kalimat tersebut menggunakan fungsi `sentence_vector()`.
#
# Hasil proses ini adalah matriks fitur numerik yang merepresentasikan setiap ulasan pengguna dalam bentuk vektor berdimensi tetap, sehingga dapat digunakan sebagai input untuk model klasifikasi.

# %%
X_train_vec = np.array([sentence_vector(tokens, embed_model) for tokens in X_train])
X_test_vec = np.array([sentence_vector(tokens, embed_model) for tokens in X_test])

X_train_vec.shape, X_test_vec.shape
# Out:
# ((11170, 100), (2793, 100))

# %% [markdown]
# ### Sanity Check by Similar Words

# %% [markdown]
# Fungsi `similar_by_word()` digunakan untuk mengevaluasi kualitas embedding dengan melihat kata-kata yang memiliki nilai cosine similarity tertinggi terhadap kata tertentu. Jika model FastText berhasil mempelajari hubungan semantik dari korpus, maka kata-kata yang muncul sebagai hasil kemiripan akan memiliki konteks penggunaan yang serupa dengan kata yang diuji.

# %%
embed_model.wv.similar_by_word("bug", topn=5)
# Out:
# [('bugs', 0.7597096562385559),
#  ('bugnya', 0.5369998216629028),
#  ('ngebug', 0.5103675723075867),
#  ('busuk', 0.4026573598384857),
#  ('logo', 0.3651379942893982)]

# %% [markdown]
# ### Sanity Check by High Order Visualization

# %% [markdown]
# Vektor hasil pelatihan FastText memiliki dimensi tinggi (dalam contoh ini 100 dimensi) sehingga sulit untuk divisualisasikan secara langsung. Oleh karena itu digunakan metode reduksi dimensi **UMAP (Uniform Manifold Approximation and Projection)** untuk memproyeksikan representasi vektor kata ke dalam ruang dua dimensi sehingga hubungan antar kata dapat divisualisasikan.
#
# Visualisasi ini membantu melihat apakah kata-kata dengan konteks yang serupa cenderung membentuk cluster yang berdekatan dalam ruang vektor.

# %%
# Melakukan reduksi dimensi word embedding menggunakan UMAP
umap_embeddings = UMAP().fit_transform(embed_model.wv.vectors)

# Membuat dataframe untuk menyimpan hasil proyeksi UMAP
# serta kata yang bersesuaian dengan setiap vektor embedding
df_umap = pd.DataFrame(umap_embeddings, columns=["umap1", "umap2"])
df_umap["word"] = embed_model.wv.index_to_key
df_umap.sample(10, random_state=SEED)
# Out:
#          umap1     umap2     word
# 1314  3.885491 -2.022173    reply
# 516   1.612136 -1.599442   pinjam
# 1154  2.723904 -0.187296  saudara
# 197   3.997915 -0.059716     face
# 467   3.808863 -3.744026    bukak
# 999   1.455404 -0.527048     ikan
# 65    2.817760 -0.899092   kantor
# 690   3.757407 -1.439460      ber
# 97    3.325192 -4.424916      bug
# 1062  5.162072 -1.020641     live

# %%
# Memvisualisasikan hubungan antar kata dalam ruang 2 dimensi
fig = px.scatter(df_umap, x="umap1", y="umap2", text="word")
fig.update_traces(textposition="top center")
fig.update_layout(
    height=800,
    title_text="Reduced FastTexst Visualization"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="749da3f7-c317-4c1c-b05f-12ffd2e8c6b5" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("749da3f7-c317-4c1c-b05f-12ffd2e8c6b5")) {                    Plotly.newPlot(                        "749da3f7-c317-4c1c-b05f-12ffd2e8c6b5",                        [{"hovertemplate":"umap1=%{x}\u003cbr\u003eumap2=%{y}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","showlegend":false,"text":["pakai","mudah","buka","banget","transaksi","guna","bagus","susah","update","masuk","baik","verifikasi","gagal","mantap","aktivasi","habis","ribet","aman","iya","wajah","saldo","error","uang","nyaman","keren","rekening","alhamdulillah","hp","eror","fitur","gk","lengkap","sulit","transfer","keluar","layan","ulang","suruh","ganggu","bikin","deh","pas","syariah","coba","gampang","lambat","minta","bayar","nasabah","atm","cepat","login","fiturnya","melulu","layar","mohon","kecewa","buruk","benar","jelek","kasih","call","suka","m-banking","data","kantor","gabisa","baru","parah","muncul","butuh","cek","pindah","solusi","cabang","daftar","manfaat","proses","gin","moga","up","laku","top","cs","terima","tarik","ganti","hilang","hasil","tf","sistem","masalah","download","potong","tangkap","dana","video","bug","pokok","menu","kartu","jaring","aneh","trus","lancar","tulis","salah","enak","hapus","kan","akses","terimakasih","pin","isi","kendala","akun","beli","senang","bintang","sdh","tunai","close","x","tetep","g","bantu","versi","kayak","kirim","apa","online","pulsa","payah","install","kerja","repot","tampil","bukti","qris","instal","jam","kaya","tabung","putih","sandi","percaya","maaf","amanah","sukses","puas","awal","buat","tutup","m","via","mutasi","capek","pilih","mantab","si","kadang","lihat","dipake","admin","informasi","muas","uninstall","selesai","tingkat","indonesia","kali","memang","bahasa","good","gara","ampun","overlapping","biar","yaa","paham","hari","sampah","duit","muka","paksa","praktis","nomor","kode","ambil","semenjak","beyond","aktif","klik","kembang","doang","bilang","erti","face","tanggal","malas","depan","rek","bankingnya","tunggu","ny","kurang","diupdate","nunggu","terang","upgrade","eh","perban","aktifasi","device","urus","in","log","gilir","lapor","kesini","best","hampir","simpan","blokir","bulan","urgent","loading","bca","rugi","shopee","notif","biaya","verivikasi","apknya","job","popups","lain","inggris","mobil","ku","kacau","jalan","e","bingung","jawab","customer","sya","otp","alih","nyusahin","notifikasi","rooted","fungsi","simple","masak","maju","bolak","nama","mandiri","ss","foto","banyak","deteksi","saran","hubung","pdhl","adu","alhamdulilah","aktivitas","cocok","rumah","kembali","gmn","scan","ujung","mungkin","lupa","nggk","tuju","bagi","gajelas","tambah","by","dikit","token","vc","root","kesel","nyesel","oke","ngebug","dr","arah","rusak","rc","tibatiba","emosi","sumpah","email","simpel","dekat","resi","mah","ngak","blank","out","slalu","mbangking","skrg","logo","macet","ubah","niat","respon","beda","detected","cuman","sms","keluh","ko","allah","assalamualaikum","nabung","internet","minggu","maintenance","rb","force","yah","malam","center","topup","pakek","perangkat","ngk","sedia","bangking","aceh","a","tagih","rumit","tolong","teman","milik","nge","org","pke","sini","hambat","wa","sinyal","gaji","rekomendasi","busuk","bank","penuh","uda","jaya","ramah","berkalikali","wifi","alas","tolol","tuh","uninstal","makan","byon","puluh","mati","pemberitahuan","tahan","jelas","kelas","samsung","aju","bukan","developer","malu","android","restart","usaha","it","bri","kedip","listrik","narik","sayang","jengkel","cari","kena","p ...

# %% [markdown]
# Dari visualisasi hasil reduksi dimensi menggunakan UMAP terlihat bahwa beberapa kata dengan konteks yang serupa cenderung berada pada area yang berdekatan. Hal ini mengindikasikan bahwa model FastText telah berhasil menangkap sebagian hubungan semantik antar kata dalam korpus. Namun demikian, visualisasi ini hanya memberikan indikasi awal dan belum cukup untuk menyimpulkan kualitas embedding secara menyeluruh.

# %% [markdown]
# # Strandardization

# %% [markdown]
# Karena beberapa algoritma yang digunakan, seperti Support Vector Machine dan Artificial Neural Network, sensitif terhadap skala fitur, maka dilakukan standardisasi menggunakan `StandardScaler` agar setiap fitur memiliki distribusi dengan mean 0 dan standar deviasi 1. Hal ini membantu proses optimasi model menjadi lebih stabil.

# %%
standard_scaler = StandardScaler()
X_train_vec = standard_scaler.fit_transform(X_train_vec)

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Label sentimen yang bersifat kategorikal (`negative`, `neutral`, `positive`) diubah menjadi representasi numerik menggunakan `LabelEncoder` agar dapat digunakan oleh algoritma machine learning.

# %%
# Encoding label sentimen mejadi representasi numerik
sentiment_encoder = LabelEncoder()

y_train_enc, y_test_enc = sentiment_encoder.fit_transform(y_train), sentiment_encoder.transform(y_test)

# %% [markdown]
# # Modelling

# %% [markdown]
# Akan dicobakan tiga algoritma:
# * Artificial Neural Network (ANN)
# * LightGBM (LGBM)
# * Support Vector Machine (SVM)

# %% [markdown]
# ## Artificial Neural Network

# %% [markdown]
# ### Training Preparation

# %%
# Inisialisasi arsitektur Artificial Neural Network
ann_model = Sequential(
    [
        Input(shape=(VECTOR_SIZE,)),
        Dense(16, activation="relu", kernel_initializer="he_normal"),
        BatchNormalization(momentum=0.9),
        Dropout(0.3),
        Dense(16, activation="relu", kernel_initializer="he_normal"),
        BatchNormalization(momentum=0.9),
        Dropout(0.3),
        Dense(3, activation="softmax"),
    ]
)
optimizer = tf.keras.optimizers.AdamW(learning_rate=0.001)
criterion = tf.keras.losses.SparseCategoricalCrossentropy()

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

# %%
ann_model.compile(
    optimizer=optimizer,
    loss=criterion,
    metrics=['accuracy']
)

# %% [markdown]
# ### Train Model

# %%
history = ann_model.fit(
    X_train_vec, y_train_enc,
    validation_split=0.2,
    epochs=10_000,
    batch_size=128,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.4444 - loss: 1.1735 - val_accuracy: 0.8599 - val_loss: 0.5968
# Epoch 2/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7959 - loss: 0.6167 - val_accuracy: 0.9033 - val_loss: 0.3800
# Epoch 3/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8833 - loss: 0.4280 - val_accuracy: 0.9127 - val_loss: 0.3133
# Epoch 4/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9146 - loss: 0.3435 - val_accuracy: 0.9163 - val_loss: 0.2940
# Epoch 5/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9204 - loss: 0.2978 - val_accuracy: 0.9172 - val_loss: 0.2855
# Epoch 6/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9231 - loss: 0.2894 - val_accuracy: 0.9181 - val_loss: 0.2801
# Epoch 7/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9238 - loss: 0.2826 - val_accuracy: 0.9185 - val_loss: 0.2771
# Epoch 8/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9230 - loss: 0.2762 - val_accuracy: 0.9203 - val_loss: 0.2749
# Epoch 9/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9234 - loss: 0.2631 - val_accuracy: 0.9212 - val_loss: 0.2729
# Epoch 10/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9283 - loss: 0.2546 - val_accuracy: 0.9226 - val_loss: 0.2681
# Epoch 11/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9277 - loss: 0.2535 - val_accuracy: 0.9208 - val_loss: 0.2675
# Epoch 12/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9292 - loss: 0.2513 - val_accuracy: 0.9208 - val_loss: 0.2658
# Epoch 13/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9327 - loss: 0.2408 - val_accuracy: 0.9203 - val_loss: 0.2650
# Epoch 14/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9314 - loss: 0.2377 - val_accuracy: 0.9208 - val_loss: 0.2633
# Epoch 15/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9312 - loss: 0.2307 - val_accuracy: 0.9203 - val_loss: 0.2624
# Epoch 16/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9332 - loss: 0.2311 - val_accuracy: 0.9194 - val_loss: 0.2617
# Epoch 17/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9316 - loss: 0.2357 - val_accuracy: 0.9203 - val_loss: 0.2614
# Epoch 18/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9332 - loss: 0.2305 - val_accuracy: 0.9217 - val_loss: 0.2566
# Epoch 19/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9369 - loss: 0.2196 - val_accuracy: 0.9212 - val_loss: 0.2558
# Epoch 20/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9345 - loss: 0.2208 - val_accuracy: 0.9226 - val_loss: 0.2570
# Epoch 21/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9381 - loss: 0.2106 - val_accuracy: 0.9226 - val_loss: 0.2528
# Epoch 22/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9373 - loss: 0.2169 - val_accuracy: 0.9199 - val_loss: 0.2536
# Epoch 23/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9331 - loss: 0.2162 - val_accuracy: 0.9230 - val_loss: 0.2517
# Epoch 24/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9379 - loss: 0.2154 - val_accuracy: 0.9221 - val_loss: 0.2529
# Epoch 25/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9403 - loss: 0.2082 - val_accuracy: 0.9217 - val_loss: 0.2498
# Epoch 26/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9369 - loss: 0.2085 - val_accuracy: 0.9221 - val_loss: 0.2516
# Epoch 27/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9390 - loss: 0.2062 - val_accuracy: 0.9235 - val_loss: 0.2497
# Epoch 28/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9345 - loss: 0.2122 - val_accuracy: 0.9226 - val_loss: 0.2467
# Epoch 29/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9401 - loss: 0.2029 - val_accuracy: 0.9239 - val_loss: 0.2463
# Epoch 30/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9379 - loss: 0.1977 - val_accuracy: 0.9235 - val_loss: 0.2461
# Epoch 31/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9401 - loss: 0.1939 - val_accuracy: 0.9230 - val_loss: 0.2456
# Epoch 32/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9432 - loss: 0.1913 - val_accuracy: 0.9226 - val_loss: 0.2439
# Epoch 33/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9354 - loss: 0.1967 - val_accuracy: 0.9244 - val_loss: 0.2439
# Epoch 34/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9392 - loss: 0.2035 - val_accuracy: 0.9244 - val_loss: 0.2444
# Epoch 35/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9412 - loss: 0.1907 - val_accuracy: 0.9235 - val_loss: 0.2425
# Epoch 36/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9381 - loss: 0.1905 - val_accuracy: 0.9239 - val_loss: 0.2408
# Epoch 37/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9409 - loss: 0.1936 - val_accuracy: 0.9230 - val_loss: 0.2445
# Epoch 38/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9424 - loss: 0.1946 - val_accuracy: 0.9244 - val_loss: 0.2437
# Epoch 39/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9432 - loss: 0.1935 - val_accuracy: 0.9230 - val_loss: 0.2426
# Epoch 40/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9436 - loss: 0.1863 - val_accuracy: 0.9239 - val_loss: 0.2428
# Epoch 41/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9436 - loss: 0.1794 - val_accuracy: 0.9244 - val_loss: 0.2418
# Epoch 42/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9404 - loss: 0.1856 - val_accuracy: 0.9226 - val_loss: 0.2433
# Epoch 43/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9416 - loss: 0.1869 - val_accuracy: 0.9217 - val_loss: 0.2422
# Epoch 44/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9431 - loss: 0.1849 - val_accuracy: 0.9212 - val_loss: 0.2410
# Epoch 45/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9449 - loss: 0.1853 - val_accuracy: 0.9230 - val_loss: 0.2408
# Epoch 46/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9431 - loss: 0.1832 - val_accuracy: 0.9230 - val_loss: 0.2404
# Epoch 47/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9439 - loss: 0.1849 - val_accuracy: 0.9230 - val_loss: 0.2405
# Epoch 48/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9435 - loss: 0.1818 - val_accuracy: 0.9221 - val_loss: 0.2404
# Epoch 49/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9394 - loss: 0.1894 - val_accuracy: 0.9221 - val_loss: 0.2407
# Epoch 50/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9433 - loss: 0.1836 - val_accuracy: 0.9235 - val_loss: 0.2383
# Epoch 51/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9431 - loss: 0.1812 - val_accuracy: 0.9221 - val_loss: 0.2385
# Epoch 52/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9460 - loss: 0.1758 - val_accuracy: 0.9239 - val_loss: 0.2387
# Epoch 53/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9453 - loss: 0.1831 - val_accuracy: 0.9226 - val_loss: 0.2377
# Epoch 54/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9439 - loss: 0.1739 - val_accuracy: 0.9235 - val_loss: 0.2384
# Epoch 55/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9428 - loss: 0.1784 - val_accuracy: 0.9226 - val_loss: 0.2400
# Epoch 56/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9412 - loss: 0.1764 - val_accuracy: 0.9235 - val_loss: 0.2420
# Epoch 57/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9444 - loss: 0.1768 - val_accuracy: 0.9239 - val_loss: 0.2396
# Epoch 58/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9467 - loss: 0.1697 - val_accuracy: 0.9221 - val_loss: 0.2417
# Epoch 59/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9440 - loss: 0.1752 - val_accuracy: 0.9226 - val_loss: 0.2408
# Epoch 60/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9447 - loss: 0.1723 - val_accuracy: 0.9239 - val_loss: 0.2409
# Epoch 61/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9444 - loss: 0.1699 - val_accuracy: 0.9235 - val_loss: 0.2428
# Epoch 62/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9436 - loss: 0.1751 - val_accuracy: 0.9226 - val_loss: 0.2381
# Epoch 63/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9455 - loss: 0.1711 - val_accuracy: 0.9230 - val_loss: 0.2390
# Epoch 64/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9461 - loss: 0.1675 - val_accuracy: 0.9226 - val_loss: 0.2389
# Epoch 65/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9458 - loss: 0.1735 - val_accuracy: 0.9239 - val_loss: 0.2395
# Epoch 66/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9461 - loss: 0.1718 - val_accuracy: 0.9217 - val_loss: 0.2390
# Epoch 67/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9436 - loss: 0.1689 - val_accuracy: 0.9226 - val_loss: 0.2404
# Epoch 68/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9462 - loss: 0.1666 - val_accuracy: 0.9221 - val_loss: 0.2388
# Epoch 69/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9444 - loss: 0.1639 - val_accuracy: 0.9221 - val_loss: 0.2395
# Epoch 70/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9453 - loss: 0.1719 - val_accuracy: 0.9226 - val_loss: 0.2388
# Epoch 71/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9482 - loss: 0.1644 - val_accuracy: 0.9230 - val_loss: 0.2419
# Epoch 72/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9444 - loss: 0.1645 - val_accuracy: 0.9239 - val_loss: 0.2417
# Epoch 73/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9460 - loss: 0.1667 - val_accuracy: 0.9226 - val_loss: 0.2425

# %%
plot_history(history)

# %% [markdown]
# Dari grafik training loss dan validation loss terlihat bahwa model telah mencapai kondisi konvergen. Selain itu, Terdapat perbedaan antara training dan validation metrics, sehingga terlihat indikasi adanya overfitting.

# %% [markdown]
# ### Model Evaluation

# %%
ann_metrics_df = model_eval(ann_model, X_test_vec, y_test_enc, standard_scaler, sentiment_encoder)
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %% [markdown]
# Berdasarkan confusion matrix, model mampu memprediksi kelas `negative` dan `positive` dengan cukup baik. Hal ini terlihat dari jumlah prediksi benar yang relatif tinggi pada kedua kelas tersebut.
#
# Namun, performa model pada kelas `neutral` masih cukup rendah. Sebagian besar data berlabel `neutral` diprediksi sebagai `negative`. Hal ini menunjukkan bahwa model mengalami kesulitan dalam membedakan pola fitur antara kelas `neutral` dan `negative`.
#
# Salah satu kemungkinan penyebabnya adalah ketidakseimbangan distribusi data antar kelas, di mana jumlah data neutral jauh lebih sedikit dibandingkan dengan kelas lainnya. Kondisi ini menyebabkan model kurang mampu mempelajari karakteristik dari kelas `neutral`.

# %%
ann_metrics_df
# Out:
#    Accuracy  Precision    Recall  F1 Score
# 0  0.936627   0.926151  0.936627  0.670545

# %% [markdown]
# Meskipun nilai accuracy cukup tinggi, nilai F1-macro relatif lebih rendah. Hal ini menunjukkan bahwa performa model tidak merata pada semua kelas, khususnya pada kelas `neutral` yang memiliki jumlah data lebih sedikit.

# %% [markdown]
# ##  Light Gradient-Boosting Machine

# %% [markdown]
# ### Train Model

# %%
params = {
    "boosting_type": Categorical(["gbdt", "dart"], prior=None),
    "num_leaves": Integer(20, 150),
    "max_depth": Integer(3, 12),
    "learning_rate": Real(0.01, 0.3, prior="log-uniform"),
    "min_child_samples": Integer(5, 100),
    "min_child_weight": Real(1e-3, 10, prior="log-uniform"),
    "subsample": Real(0.5, 1.0, prior="uniform"),
    "colsample_bytree": Real(0.5, 1.0, prior="uniform"),
    "reg_alpha": Real(1e-9, 100.0, prior="log-uniform"),
    "reg_lambda": Real(1e-9, 100.0, prior="log-uniform"),
    "min_split_gain": Real(0.0, 1.0),
    "max_bin": Integer(100, 500)
}

# Inisialisasi Bayesian Search
lgb_model = BayesSearchCV(
    estimator=LGBMClassifier(objective="multiclass", num_class=3, n_jobs=-1, random_state=SEED),
    search_spaces=params,
    cv=5,
    scoring="f1_macro",
    n_iter=100,
    n_jobs=-1,
    verbose=1,
    random_state=SEED,
)
lgb_model.fit(X_train_vec, y_train_enc)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015594 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 50000
# [LightGBM] [Info] Number of data points in the train set: 11170, number of used features: 100
# [LightGBM] [Info] Start training from score -0.446959
# [LightGBM] [Info] Start training from score -3.664995
# [LightGBM] [Info] Start training from score -1.094146
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# BayesSearchCV(cv=5,
#               estimator=LGBMClassifier(n_jobs=-1, num_class=3,
#                                        objective='multiclass',
#                                        random_state=1010),
#               n_iter=100, n_jobs=-1, random_state=1010, scoring='f1_macro',
#               search_spaces={'boosting_type': Categorical(categories=('gbdt', 'dart'), prior=None),
#                              'colsample_bytree': Real(low=0.5, high=1.0, prior='uniform', transform='normalize'),
#                              'learning_rate': Real(l...
#                              'min_split_gain': Real(low=0.0, high=1.0, prior='uniform', transform='normalize'),
#                              'num_leaves': Integer(low=20, high=150, prior='uniform', transform='normalize'),
#                              'reg_alpha': Real(low=1e-09, high=100.0, prior='log-uniform', transform='normalize'),
#                              'reg_lambda': Real(low=1e-09, high=100.0, prior='log-uniform', transform='normalize'),
#                              'subsample': Real(low=0.5, high=1.0, prior='uniform', transform='normalize')},
#               verbose=1)

# %%
# Menampilkan hyperparameter terbaik dari Bayesian Search
print("Best parameters:", lgb_model.best_params_)
print("Best CV Score:", lgb_model.best_score_)
print("Test Score:", lgb_model.score(X_test_vec, y_test_enc))
# Out:
# Best parameters: OrderedDict({'boosting_type': 'gbdt', 'colsample_bytree': 0.6305271372630075, 'learning_rate': 0.29999999999999993, 'max_bin': 500, 'max_depth': 3, 'min_child_samples': 5, 'min_child_weight': 0.011833396977692288, 'min_split_gain': 0.8053517880665638, 'num_leaves': 150, 'reg_alpha': 0.0008950720082209401, 'reg_lambda': 0.0006384690559350793, 'subsample': 1.0})
# Best CV Score: 0.7129107771202093
# Test Score: 0.6683416789769435
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LGBMClassifier was fitted with feature names

# %% [markdown]
# Terlihat adanya indikasi overfitting ringan karena nilai F1-macro pada data validasi cross-validation (71.3%) lebih tinggi dibandingkan performa pada data test (64.8%).

# %% [markdown]
# ### Model Evaluation

# %%
lgb_metrics_df = model_eval(lgb_model, X_test_vec, y_test_enc, standard_scaler, sentiment_encoder)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LGBMClassifier was fitted with feature names

# %% [markdown]
# Berdasarkan confusion matrix, model mampu memprediksi kelas `negative` dan `positive` dengan cukup baik. Hal ini terlihat dari jumlah prediksi benar yang relatif tinggi pada kedua kelas tersebut.
#
# Namun, performa model pada kelas `neutral` masih cukup rendah. Sebagian besar data berlabel `neutral` diprediksi sebagai `negative`. Hal ini menunjukkan bahwa model mengalami kesulitan dalam membedakan pola fitur antara kelas `neutral` dan `negative`.
#
# Salah satu kemungkinan penyebabnya adalah ketidakseimbangan distribusi data antar kelas, di mana jumlah data neutral jauh lebih sedikit dibandingkan dengan kelas lainnya. Kondisi ini menyebabkan model kurang mampu mempelajari karakteristik dari kelas `neutral`.

# %%
lgb_metrics_df
# Out:
#    Accuracy  Precision    Recall  F1 Score
# 0  0.935553   0.926933  0.935553   0.70258

# %% [markdown]
# Model LGBM berhasil mendapatkan 93.6% accuracy, 92.7% Weighted Precision, 93.6% Weighted Recall, dan 70.2% F1-macro pada data test.

# %% [markdown]
# ## Support Vector Machine

# %% [markdown]
# ### Train Model

# %%
params = {
    "kernel": Categorical(["linear", "poly", "rbf", "sigmoid"], prior=None),
    "gamma": Real(low=1e-3, high=1e3, prior="log-uniform", transform="identity"),
    "C": Real(low=1e-3, high=1e3, prior="log-uniform", transform="identity"),
    "degree": Categorical([2, 3], prior=None)
}

# Inisialisasi Bayesian Search
svc_model = BayesSearchCV(
    estimator=SVC(max_iter=500, random_state=42),
    search_spaces=params,
    cv=5,
    scoring="f1_macro",
    n_iter=100,
    n_jobs=-1,
    verbose=1,
    random_state=SEED,
)
svc_model.fit(X_train_vec, y_train_enc)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning:
#
# Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# BayesSearchCV(cv=5, estimator=SVC(max_iter=500, random_state=42), n_iter=100,
#               n_jobs=-1, random_state=1010, scoring='f1_macro',
#               search_spaces={'C': Real(low=0.001, high=1000.0, prior='log-uniform', transform='normalize'),
#                              'degree': Categorical(categories=(2, 3), prior=None),
#                              'gamma': Real(low=0.001, high=1000.0, prior='log-uniform', transform='normalize'),
#                              'kernel': Categorical(categories=('linear', 'poly', 'rbf', 'sigmoid'), prior=None)},
#               verbose=1)

# %%
# Menampilkan hyperparameter terbaik dari Bayesian Search
print("Best parameters:", svc_model.best_params_)
print("Best CV Score:", svc_model.best_score_)
print("Test Score:", svc_model.score(X_test_vec, y_test_enc))
# Out:
# Best parameters: OrderedDict({'C': 27.146670459027, 'degree': 3, 'gamma': 0.006138424967567442, 'kernel': 'rbf'})
# Best CV Score: 0.7339969516788627
# Test Score: 0.636155557876742

# %% [markdown]
# Terindikasi ada cukup overfitting karena Best CV Score 73.4%, sedangkan test score 63.6%.

# %% [markdown]
# ### Model Evaluation

# %%
svc_metrics_df = model_eval(svc_model, X_test_vec, y_test_enc, standard_scaler, sentiment_encoder)

# %% [markdown]
# Berdasarkan confusion matrix, model mampu memprediksi kelas `negative` dan `positive` dengan cukup baik. Hal ini terlihat dari jumlah prediksi benar yang relatif tinggi pada kedua kelas tersebut.
#
# Namun, performa model pada kelas `neutral` masih cukup rendah. Sebagian besar data berlabel `neutral` diprediksi sebagai `negative`. Hal ini menunjukkan bahwa model mengalami kesulitan dalam membedakan pola fitur antara kelas `neutral` dan `negative`.
#
# Salah satu kemungkinan penyebabnya adalah ketidakseimbangan distribusi data antar kelas, di mana jumlah data neutral jauh lebih sedikit dibandingkan dengan kelas lainnya. Kondisi ini menyebabkan model kurang mampu mempelajari karakteristik dari kelas `neutral`.

# %%
svc_metrics_df
# Out:
#    Accuracy  Precision    Recall  F1 Score
# 0  0.921232   0.915981  0.921232  0.731291

# %% [markdown]
# Model SVM berhasil mendapatkan 92.1% accuracy, 91.6% Weighted Precision, 92.1% Weighted Recall, dan 73.1% F1-macro pada data test.

# %% [markdown]
# # Conclusion

# %%
# Menggabungkan metrik evaluasi dari ketiga model
metrics = {
    "ANN": ann_metrics_df,
    "LGBM": lgb_metrics_df,
    "SVC": svc_metrics_df
}

# Menggabungkan dataframe metrik menjadi satu tabel
metrics_df = pd.concat(metrics)
metrics_df.index = metrics_df.index.droplevel(1)
metrics_df.index.name = "Model"
metrics_df
# Out:
#        Accuracy  Precision    Recall  F1 Score
# Model
# ANN    0.936627   0.926151  0.936627  0.670545
# LGBM   0.935553   0.926933  0.935553  0.702580
# SVC    0.921232   0.915981  0.921232  0.731291

# %% [markdown]
# Ketiga model menunjukkan pola kesalahan yang serupa pada confusion matrix, yaitu kesulitan dalam memprediksi kelas `neutral`. Sebagian besar data berlabel `neutral` diprediksi sebagai `negative`. Hal ini mengindikasikan bahwa permasalahan utama kemungkinan berasal dari karakteristik dataset, khususnya ketidakseimbangan distribusi kelas, di mana jumlah data `neutral` jauh lebih sedikit dibandingkan kelas lainnya. Kondisi tersebut menyebabkan model kurang mampu mempelajari pola yang representatif untuk kelas `neutral`. Oleh karena itu, pada tahap pengembangan model selanjutnya dapat dipertimbangkan penerapan teknik penanganan *class imbalance*, seperti *class weighting*, *oversampling*, atau *data augmentation*.
#
# Berdasarkan perbandingan metrik evaluasi, model **SVM** memiliki nilai **F1-macro tertinggi**, yang menunjukkan kemampuan yang relatif lebih baik dalam menangani distribusi kelas yang tidak seimbang. Walaupun bukan model dengan nilai accuracy tertinggi, dalam proyek ini ditetapkan bahwa model harus mencapai nilai **accuracy minimal sebesar 92%**, dan model SVM telah memenuhi ambang batas tersebut. Oleh karena itu, **SVM dipilih sebagai model terbaik**, karena tidak hanya memenuhi kriteria accuracy yang ditetapkan, tetapi juga menunjukkan performa yang lebih baik dalam menjaga keseimbangan kinerja antar kelas berdasarkan metrik F1-macro.

# %% [markdown]
# # Save Model Bundle

# %%
# Menyimpan pipeline model yang terdiri dari:
# - FastText embedding
# - StandardScaler
# - LabelEncoder
# - Model klasifikasi SVM
joblib.dump({
    "embed_model": embed_model,
    "scaler": standard_scaler,
    "encoder": sentiment_encoder,
    "model": svc_model
}, "fasttex_svc.joblib")
# Out:
# ['fasttex_svc.joblib']
