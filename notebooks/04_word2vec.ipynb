# %% [markdown]
# # Import Dependencies

# %% [markdown]
# Pada tahap ini dilakukan instalasi pustaka (*library*) yang diperlukan untuk menjalankan proses analisis dan pemodelan **Natural Language Processing (NLP)**. Library `gensim` digunakan untuk membangun model **Word2Vec**, yaitu metode *word embedding* yang merepresentasikan kata dalam bentuk vektor numerik sehingga dapat menangkap hubungan semantik antar kata. Selain itu, library `scikit-optimize` digunakan untuk melakukan optimasi hiperparameter model melalui pendekatan *Bayesian Optimization*.

# %%
# !pip install gensim scikit-optimize
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.12/dist-packages (0.10.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.5.3)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (26.2.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (2.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.6.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (26.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.6.0)

# %% [markdown]
# Nilai *random seed* ditetapkan untuk memastikan proses eksperimen bersifat ***reproducible***, sehingga hasil pelatihan model dapat direproduksi kembali ketika kode dijalankan ulang. Parameter `VECTOR_SIZE` digunakan untuk menentukan dimensi vektor pada model **Word2Vec**.

# %%
SEED = 1010
VECTOR_SIZE = 100

# %%
import joblib
import nltk
import numpy as np
import pandas as pd
import plotly.express as px
import tensorflow as tf
from gensim.models import Word2Vec
from lightgbm import LGBMClassifier
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC
from skopt import BayesSearchCV
from skopt.space import Categorical, Integer, Real
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, Input
from tensorflow.keras.models import Sequential
from umap import UMAP

# custom module
from utils import model_eval, plot_history, sentence_vector

nltk.download("punkt_tab")

tf.random.set_seed(SEED)
np.random.seed(SEED)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# # Load Data

# %% [markdown]
# Dataset dimuat menggunakan fungsi `read_csv()` dari pustaka `pandas`. Dari dataset yang tersedia, hanya dua kolom yang digunakan dalam penelitian ini, yaitu kolom `content` yang berisi teks ulasan pengguna dan kolom `sentiment` yang berisi label sentimen.

# %%
# Memuat dataset
df = pd.read_csv("clean_review_bsi_mobile.csv")
df = df[['content', 'sentiment']]
df.sample(10, random_state=SEED)
# Out:
#                                                  content sentiment
# 6393   transaksi susah ribet transfer orangkirain gag...  negative
# 823                                      top up dana gk   negative
# 12199                 force close melulu qr eror mlu deh  negative
# 2259   paksa ganti akses uang situ suruh ganti pakai ...  negative
# 3632                                          mudah guna  positive
# 9423   apknya ui banget pakai syariah capek banget ba...  negative
# 13536  pakai kendalasemua bagus profil layan pinjaman...  positive
# 8017   baru deteksi device rooted device gx rooted al...  negative
# 13047                                             ganggu  negative
# 3501                                          buka habis  negative

# %%
# Tampilkan informasi umum tentang dataset
print("\nInformasi dataset:")
df.info()
# Out:
# Informasi dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13969 entries, 0 to 13968
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   content    13963 non-null  object
#  1   sentiment  13969 non-null  object
# dtypes: object(2)
# memory usage: 218.4+ KB

# %% [markdown]
# Berdasarkan informasi dataset, terdapat **13.969 baris data** dengan dua atribut utama, yaitu teks ulasan (`content`) dan label sentimen (`sentiment`).

# %%
# Cek missing values
print("\nMissing values per fitur:")
print(df.isnull().sum())
# Out:
# Missing values per fitur:
# content      6
# sentiment    0
# dtype: int64

# %% [markdown]
# Selanjutnya dilakukan pemeriksaan terhadap *missing values* pada setiap fitur. Hasil pemeriksaan menunjukkan terdapat **6 nilai kosong pada kolom `content`**. Data yang memiliki nilai kosong kemudian dihapus menggunakan metode `dropna()` untuk menjaga kualitas data yang digunakan dalam proses pelatihan model.

# %%
# Menghapus baris dengan missing values
df.dropna(inplace=True)

print("\nInformasi dataset setelah penanganan missing values:")
df.info()
# Out:
# Informasi dataset setelah penanganan missing values:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13963 entries, 0 to 13968
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   content    13963 non-null  object
#  1   sentiment  13963 non-null  object
# dtypes: object(2)
# memory usage: 327.3+ KB

# %% [markdown]
# Setelah proses penanganan *missing values*, jumlah data yang tersisa adalah **13.963 baris** yang selanjutnya digunakan dalam proses pemodelan.

# %% [markdown]
# # Data Splitting

# %%
# Memisahkan fitur dengan label
X = df['content']
y = df['sentiment']

# %%
# Bagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=SEED)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11170,), (2793,), (11170,), (2793,))

# %% [markdown]
# Data kemudian dibagi menjadi data latih dan data uji menggunakan teknik *stratified train-test split* berdasarkan label `sentiment` dengan proporsi **80% data latih dan 20% data uji**. Pendekatan ini digunakan untuk memastikan distribusi kelas sentimen pada data latih dan data uji tetap seimbang dengan distribusi pada dataset asli.

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ## Tokenization

# %% [markdown]
# Pada tahap ini dilakukan **tokenisasi** terhadap teks pada kolom `content` menggunakan fungsi `word_tokenize()` dari pustaka `nltk`. Proses tokenisasi bertujuan untuk memecah teks ulasan menjadi unit kata (*tokens*) sehingga dapat diproses oleh model Word2Vec dalam tahap pembelajaran representasi kata.

# %%
# Melakukan tokenisasi terhadap kolom `content`
X_train, X_test = X_train.apply(word_tokenize), X_test.apply(word_tokenize)

X_train.sample(10, random_state=SEED)
# Out:
# 6798            [keren, mudahlebih, efektif, moga, amanah]
# 8352                                              [mantap]
# 7365     [baik, sistem, operasi, qris, scan, qr, susah,...
# 10664                                             [kecewa]
# 3197                                               [bagus]
# 2726     [alhamdulillah, aman, percaya, pakai, benar, b...
# 11567    [online, mudah, lha, susah, akses, habis, teru...
# 9625                    [iya, verifikasi, aktifasi, gagal]
# 5133                       [terkadang, lambat, konek, iya]
# 9840                         [iya, transfer, force, close]
# Name: content, dtype: object

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# Setelah proses tokenisasi, dilakukan pelatihan model **Word2Vec** untuk menghasilkan representasi vektor dari setiap kata. Model Word2Vec mempelajari hubungan semantik antar kata berdasarkan konteks kemunculannya dalam kalimat.
#
# Pada penelitian ini digunakan beberapa parameter utama, yaitu:
#
# * `vector_size = 100` untuk menentukan dimensi vektor kata
#
# * `window = 10` untuk menentukan jumlah kata konteks yang diperhatikan di sekitar kata target
#
# * `min_count = 5` untuk mengabaikan kata yang muncul kurang dari 5 kali
#
# * `epochs = 100` untuk jumlah iterasi pelatihan model

# %%
# Melatih model Word2Vec untuk mempelajari representasi vektor kata
embed_model = Word2Vec(
    sentences=X_train,
    vector_size=VECTOR_SIZE,
    window=10,
    min_count=5,
    workers=4,
    epochs=100,
    seed=SEED
)

# %% [markdown]
# Setelah model Word2Vec dilatih, langkah selanjutnya adalah melakukan **ekstraksi fitur kalimat**. Setiap kalimat direpresentasikan dalam bentuk vektor dengan cara menggabungkan vektor kata yang terdapat dalam kalimat tersebut menggunakan fungsi `sentence_vector()`.
#
# Hasil proses ini adalah matriks fitur numerik yang merepresentasikan setiap ulasan pengguna dalam bentuk vektor berdimensi tetap, sehingga dapat digunakan sebagai input untuk model klasifikasi.

# %%
X_train_vec = np.array([sentence_vector(tokens, embed_model) for tokens in X_train])
X_test_vec = np.array([sentence_vector(tokens, embed_model) for tokens in X_test])

X_train_vec.shape, X_test_vec.shape
# Out:
# ((11170, 100), (2793, 100))

# %% [markdown]
# ### Sanity Check by Similar Words

# %% [markdown]
# Fungsi `similar_by_word()` digunakan untuk mengevaluasi kualitas embedding dengan melihat kata-kata yang memiliki nilai cosine similarity tertinggi terhadap kata tertentu. Jika model Word2Vec berhasil mempelajari hubungan semantik dari korpus, maka kata-kata yang muncul sebagai hasil kemiripan akan memiliki konteks penggunaan yang serupa dengan kata yang diuji.

# %%
embed_model.wv.similar_by_word("bug", topn=5)
# Out:
# [('stuck', 0.2870144248008728),
#  ('hang', 0.2770722806453705),
#  ('adzan', 0.2553107738494873),
#  ('putih', 0.2525300085544586),
#  ('simpan', 0.24519413709640503)]

# %% [markdown]
# ### Sanity Check by High Order Visualization

# %% [markdown]
# Vektor hasil pelatihan Word2Vec memiliki dimensi tinggi (dalam contoh ini 100 dimensi) sehingga sulit untuk divisualisasikan secara langsung. Oleh karena itu digunakan metode reduksi dimensi **UMAP (Uniform Manifold Approximation and Projection)** untuk memproyeksikan representasi vektor kata ke dalam ruang dua dimensi sehingga hubungan antar kata dapat divisualisasikan.
#
# Visualisasi ini membantu melihat apakah kata-kata dengan konteks yang serupa cenderung membentuk cluster yang berdekatan dalam ruang vektor.

# %%
# Melakukan reduksi dimensi word embedding menggunakan UMAP
umap_embeddings = UMAP().fit_transform(embed_model.wv.vectors)

# Membuat dataframe untuk menyimpan hasil proyeksi UMAP
# serta kata yang bersesuaian dengan setiap vektor embedding
df_umap = pd.DataFrame(umap_embeddings, columns=["umap1", "umap2"])
df_umap["word"] = embed_model.wv.index_to_key
df_umap.sample(10, random_state=SEED)
# Out:
#          umap1      umap2        word
# 1239  6.416432  12.667789       nyaaa
# 444   6.797758  10.427066       nyoba
# 834   4.811627  14.657681      kerenn
# 566   5.712080  12.598549         woi
# 1177  4.251338  12.491561    nonaktif
# 1199  4.396407  14.333005  insyaallah
# 1229  2.378477  11.894135       walet
# 267   4.413613  12.401642      banyak
# 908   5.890634   9.908074      donlod
# 82    3.580639  13.329196        laku

# %%
# Memvisualisasikan hubungan antar kata dalam ruang 2 dimensi
fig = px.scatter(df_umap, x="umap1", y="umap2", text="word")
fig.update_traces(textposition="top center")
fig.update_layout(
    height=800,
    title_text="Reduced Word2Vec Visualization"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fa2eb83d-08e8-494e-b097-0d8cd421ee3a" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa2eb83d-08e8-494e-b097-0d8cd421ee3a")) {                    Plotly.newPlot(                        "fa2eb83d-08e8-494e-b097-0d8cd421ee3a",                        [{"hovertemplate":"umap1=%{x}\u003cbr\u003eumap2=%{y}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","showlegend":false,"text":["pakai","mudah","buka","banget","transaksi","guna","bagus","susah","update","masuk","baik","verifikasi","gagal","mantap","ribet","aman","iya","habis","aktivasi","wajah","saldo","uang","nyaman","keren","error","rekening","alhamdulillah","eror","hp","lengkap","fitur","gk","transfer","keluar","sulit","layan","ulang","bikin","suruh","deh","pas","ganggu","syariah","coba","gampang","minta","lambat","bayar","atm","cepat","fiturnya","login","nasabah","layar","melulu","kecewa","buruk","mohon","benar","jelek","kasih","data","kantor","suka","butuh","cabang","call","proses","muncul","baru","daftar","m-banking","cek","gabisa","up","pindah","solusi","parah","gin","tarik","top","manfaat","laku","moga","terima","hasil","cs","sistem","hilang","potong","tf","dana","ganti","tangkap","download","masalah","pokok","kartu","video","bug","trus","menu","tulis","lancar","aneh","enak","salah","hapus","kendala","kan","jaring","akun","tunai","akses","x","terimakasih","pin","senang","bintang","beli","tetep","isi","close","tampil","sdh","kirim","kerja","bukti","g","versi","kayak","jam","payah","online","qris","pulsa","buat","puas","amanah","bantu","apa","instal","putih","sandi","maaf","percaya","kaya","pilih","install","tutup","tabung","m","repot","sukses","si","mutasi","mantab","awal","informasi","tingkat","selesai","memang","capek","biar","kali","admin","indonesia","paham","via","dipake","overlapping","praktis","bahasa","lihat","yaa","gara","muas","kadang","duit","depan","aktif","bankingnya","ambil","beyond","ampun","kembang","uninstall","tanggal","malas","good","hari","nomor","muka","diupdate","ny","klik","erti","urus","doang","upgrade","nunggu","kurang","terang","blokir","in","tunggu","sampah","log","face","loading","perban","eh","simpan","rek","kode","device","paksa","bca","semenjak","lapor","urgent","bilang","ngak","bagi","aktifasi","maju","shopee","kesini","biaya","nyusahin","jawab","verivikasi","gilir","best","mobil","notif","inggris","foto","simple","jalan","masak","popups","gmn","rugi","saran","apknya","hampir","mandiri","lain","job","kacau","ku","ujung","scan","dr","customer","bulan","bingung","email","sya","rooted","skrg","adu","pdhl","ss","e","fungsi","banyak","cocok","hubung","bolak","gaji","vc","tibatiba","otp","nama","kembali","simpel","ramah","notifikasi","niat","by","rumah","alhamdulilah","detected","nyesel","tuju","oke","assalamualaikum","bangking","nggk","mungkin","ngebug","deteksi","emosi","token","a","aceh","slalu","aktivitas","internet","mbangking","rusak","lupa","maintenance","respon","dekat","alih","root","kesel","topup","ko","tambah","logo","nabung","kena","sms","mah","cuman","rc","sumpah","force","wifi","out","tolong","gajelas","center","tagih","yah","tuh","beda","malu","allah","resi","macet","keluh","malam","tolol","tahan","samsung","pke","uninstal","minggu","kelas","bukan","sinyal","ewallet","aktivasinya","pemberitahuan","sini","bank","dikit","usaha","mesti","makan","it","blank","pakek","byon","arah","sedia","penuh","org","listrik","rumit","rb","developer","hambat","restart","fiturfitur","perangkat","mobilenya","nge","berkalikali","jaya","bngt","cari","mati","narik","ubah","ayo","trouble","user","rekomendasi","jual","alas","jamin","pusin ...

# %% [markdown]
# Dari visualisasi hasil reduksi dimensi menggunakan UMAP terlihat bahwa beberapa kata dengan konteks yang serupa cenderung berada pada area yang berdekatan. Hal ini mengindikasikan bahwa model Word2Vec telah berhasil menangkap sebagian hubungan semantik antar kata dalam korpus. Namun demikian, visualisasi ini hanya memberikan indikasi awal dan belum cukup untuk menyimpulkan kualitas embedding secara menyeluruh.

# %% [markdown]
# # Standardization

# %% [markdown]
# Karena beberapa algoritma yang digunakan, seperti Support Vector Machine dan Artificial Neural Network, sensitif terhadap skala fitur, maka dilakukan standardisasi menggunakan `StandardScaler` agar setiap fitur memiliki distribusi dengan mean 0 dan standar deviasi 1. Hal ini membantu proses optimasi model menjadi lebih stabil.

# %%
standard_scaler = StandardScaler()
X_train_vec = standard_scaler.fit_transform(X_train_vec)

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Label sentimen yang bersifat kategorikal (`negative`, `neutral`, `positive`) diubah menjadi representasi numerik menggunakan `LabelEncoder` agar dapat digunakan oleh algoritma machine learning.

# %%
# Encoding label sentimen mejadi representasi numerik
sentiment_encoder = LabelEncoder()

y_train_enc, y_test_enc = sentiment_encoder.fit_transform(y_train), sentiment_encoder.transform(y_test)

# %% [markdown]
# # Modelling

# %% [markdown]
# Akan dicobakan tiga algoritma:
# * Artificial Neural Network (ANN)
# * LightGBM (LGBM)
# * Support Vector Machine (SVM)

# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Training Preparation

# %%
# Inisialisasi arsitektur Artificial Neural Network
ann_model = Sequential(
    [
        Input(shape=(VECTOR_SIZE,)),
        Dense(16, activation="relu", kernel_initializer="he_normal"),
        BatchNormalization(momentum=0.9),
        Dropout(0.3),
        Dense(16, activation="relu", kernel_initializer="he_normal"),
        BatchNormalization(momentum=0.9),
        Dropout(0.3),
        Dense(3, activation="softmax"),
    ]
)
optimizer = tf.keras.optimizers.AdamW(learning_rate=0.001)
criterion = tf.keras.losses.SparseCategoricalCrossentropy()

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

# %%
ann_model.compile(
    optimizer=optimizer,
    loss=criterion,
    metrics=['accuracy']
)

# %% [markdown]
# ### Train Model

# %%
history = ann_model.fit(
    X_train_vec, y_train_enc,
    validation_split=0.2,
    epochs=10_000,
    batch_size=128,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4249 - loss: 1.3305 - val_accuracy: 0.8554 - val_loss: 0.5142
# Epoch 2/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7345 - loss: 0.6859 - val_accuracy: 0.9167 - val_loss: 0.3226
# Epoch 3/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8498 - loss: 0.4590 - val_accuracy: 0.9288 - val_loss: 0.2625
# Epoch 4/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8864 - loss: 0.3835 - val_accuracy: 0.9315 - val_loss: 0.2376
# Epoch 5/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9006 - loss: 0.3457 - val_accuracy: 0.9338 - val_loss: 0.2276
# Epoch 6/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9070 - loss: 0.3182 - val_accuracy: 0.9351 - val_loss: 0.2208
# Epoch 7/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9138 - loss: 0.3088 - val_accuracy: 0.9355 - val_loss: 0.2174
# Epoch 8/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9152 - loss: 0.3018 - val_accuracy: 0.9355 - val_loss: 0.2131
# Epoch 9/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9137 - loss: 0.2948 - val_accuracy: 0.9351 - val_loss: 0.2103
# Epoch 10/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9215 - loss: 0.2772 - val_accuracy: 0.9360 - val_loss: 0.2077
# Epoch 11/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9166 - loss: 0.2867 - val_accuracy: 0.9360 - val_loss: 0.2055
# Epoch 12/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9203 - loss: 0.2813 - val_accuracy: 0.9373 - val_loss: 0.2034
# Epoch 13/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9218 - loss: 0.2688 - val_accuracy: 0.9369 - val_loss: 0.2011
# Epoch 14/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9269 - loss: 0.2613 - val_accuracy: 0.9378 - val_loss: 0.2002
# Epoch 15/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9225 - loss: 0.2665 - val_accuracy: 0.9378 - val_loss: 0.1993
# Epoch 16/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9278 - loss: 0.2549 - val_accuracy: 0.9382 - val_loss: 0.1978
# Epoch 17/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9260 - loss: 0.2530 - val_accuracy: 0.9387 - val_loss: 0.1962
# Epoch 18/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9212 - loss: 0.2555 - val_accuracy: 0.9391 - val_loss: 0.1944
# Epoch 19/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9257 - loss: 0.2467 - val_accuracy: 0.9409 - val_loss: 0.1945
# Epoch 20/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9280 - loss: 0.2406 - val_accuracy: 0.9400 - val_loss: 0.1928
# Epoch 21/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9286 - loss: 0.2332 - val_accuracy: 0.9405 - val_loss: 0.1938
# Epoch 22/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.2339 - val_accuracy: 0.9400 - val_loss: 0.1930
# Epoch 23/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9291 - loss: 0.2385 - val_accuracy: 0.9405 - val_loss: 0.1922
# Epoch 24/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9275 - loss: 0.2390 - val_accuracy: 0.9400 - val_loss: 0.1916
# Epoch 25/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9296 - loss: 0.2288 - val_accuracy: 0.9391 - val_loss: 0.1904
# Epoch 26/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9320 - loss: 0.2253 - val_accuracy: 0.9396 - val_loss: 0.1900
# Epoch 27/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9295 - loss: 0.2311 - val_accuracy: 0.9396 - val_loss: 0.1890
# Epoch 28/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9289 - loss: 0.2319 - val_accuracy: 0.9396 - val_loss: 0.1892
# Epoch 29/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9329 - loss: 0.2195 - val_accuracy: 0.9391 - val_loss: 0.1894
# Epoch 30/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9335 - loss: 0.2151 - val_accuracy: 0.9423 - val_loss: 0.1877
# Epoch 31/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9330 - loss: 0.2181 - val_accuracy: 0.9387 - val_loss: 0.1870
# Epoch 32/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9302 - loss: 0.2251 - val_accuracy: 0.9387 - val_loss: 0.1868
# Epoch 33/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9311 - loss: 0.2188 - val_accuracy: 0.9405 - val_loss: 0.1863
# Epoch 34/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.2204 - val_accuracy: 0.9405 - val_loss: 0.1862
# Epoch 35/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9319 - loss: 0.2125 - val_accuracy: 0.9391 - val_loss: 0.1858
# Epoch 36/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9348 - loss: 0.2054 - val_accuracy: 0.9414 - val_loss: 0.1845
# Epoch 37/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.2156 - val_accuracy: 0.9405 - val_loss: 0.1834
# Epoch 38/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9341 - loss: 0.2098 - val_accuracy: 0.9405 - val_loss: 0.1821
# Epoch 39/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9323 - loss: 0.2075 - val_accuracy: 0.9405 - val_loss: 0.1826
# Epoch 40/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9318 - loss: 0.2150 - val_accuracy: 0.9387 - val_loss: 0.1812
# Epoch 41/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9325 - loss: 0.2027 - val_accuracy: 0.9418 - val_loss: 0.1802
# Epoch 42/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9340 - loss: 0.2078 - val_accuracy: 0.9382 - val_loss: 0.1815
# Epoch 43/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.2015 - val_accuracy: 0.9373 - val_loss: 0.1809
# Epoch 44/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9406 - loss: 0.1948 - val_accuracy: 0.9387 - val_loss: 0.1797
# Epoch 45/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2006 - val_accuracy: 0.9391 - val_loss: 0.1795
# Epoch 46/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9348 - loss: 0.1993 - val_accuracy: 0.9400 - val_loss: 0.1781
# Epoch 47/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9345 - loss: 0.2054 - val_accuracy: 0.9405 - val_loss: 0.1784
# Epoch 48/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9303 - loss: 0.2084 - val_accuracy: 0.9391 - val_loss: 0.1776
# Epoch 49/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9354 - loss: 0.1930 - val_accuracy: 0.9387 - val_loss: 0.1779
# Epoch 50/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9354 - loss: 0.1961 - val_accuracy: 0.9400 - val_loss: 0.1771
# Epoch 51/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9391 - loss: 0.1920 - val_accuracy: 0.9396 - val_loss: 0.1759
# Epoch 52/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9332 - loss: 0.1952 - val_accuracy: 0.9414 - val_loss: 0.1769
# Epoch 53/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9335 - loss: 0.1971 - val_accuracy: 0.9423 - val_loss: 0.1775
# Epoch 54/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9364 - loss: 0.2002 - val_accuracy: 0.9423 - val_loss: 0.1761
# Epoch 55/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9359 - loss: 0.1999 - val_accuracy: 0.9414 - val_loss: 0.1755
# Epoch 56/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9332 - loss: 0.2006 - val_accuracy: 0.9405 - val_loss: 0.1743
# Epoch 57/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9370 - loss: 0.1932 - val_accuracy: 0.9414 - val_loss: 0.1742
# Epoch 58/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9321 - loss: 0.2000 - val_accuracy: 0.9405 - val_loss: 0.1748
# Epoch 59/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9356 - loss: 0.1855 - val_accuracy: 0.9409 - val_loss: 0.1747
# Epoch 60/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9363 - loss: 0.1945 - val_accuracy: 0.9405 - val_loss: 0.1744
# Epoch 61/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9383 - loss: 0.1902 - val_accuracy: 0.9414 - val_loss: 0.1738
# Epoch 62/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9380 - loss: 0.1892 - val_accuracy: 0.9405 - val_loss: 0.1732
# Epoch 63/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9369 - loss: 0.1968 - val_accuracy: 0.9387 - val_loss: 0.1727
# Epoch 64/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9408 - loss: 0.1814 - val_accuracy: 0.9405 - val_loss: 0.1736
# Epoch 65/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9383 - loss: 0.1908 - val_accuracy: 0.9423 - val_loss: 0.1734
# Epoch 66/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9359 - loss: 0.1866 - val_accuracy: 0.9414 - val_loss: 0.1721
# Epoch 67/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9345 - loss: 0.1910 - val_accuracy: 0.9405 - val_loss: 0.1734
# Epoch 68/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.1847 - val_accuracy: 0.9405 - val_loss: 0.1724
# Epoch 69/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9336 - loss: 0.1964 - val_accuracy: 0.9400 - val_loss: 0.1738
# Epoch 70/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9386 - loss: 0.1899 - val_accuracy: 0.9405 - val_loss: 0.1734
# Epoch 71/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9396 - loss: 0.1858 - val_accuracy: 0.9414 - val_loss: 0.1732
# Epoch 72/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9356 - loss: 0.1885 - val_accuracy: 0.9409 - val_loss: 0.1728
# Epoch 73/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9364 - loss: 0.1852 - val_accuracy: 0.9409 - val_loss: 0.1705
# Epoch 74/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9378 - loss: 0.1847 - val_accuracy: 0.9414 - val_loss: 0.1701
# Epoch 75/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9405 - loss: 0.1846 - val_accuracy: 0.9409 - val_loss: 0.1722
# Epoch 76/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9403 - loss: 0.1832 - val_accuracy: 0.9414 - val_loss: 0.1721
# Epoch 77/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9417 - loss: 0.1802 - val_accuracy: 0.9405 - val_loss: 0.1731
# Epoch 78/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9388 - loss: 0.1863 - val_accuracy: 0.9423 - val_loss: 0.1734
# Epoch 79/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.1819 - val_accuracy: 0.9423 - val_loss: 0.1714
# Epoch 80/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9345 - loss: 0.1875 - val_accuracy: 0.9418 - val_loss: 0.1722
# Epoch 81/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9370 - loss: 0.1811 - val_accuracy: 0.9418 - val_loss: 0.1726
# Epoch 82/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.1763 - val_accuracy: 0.9400 - val_loss: 0.1734
# Epoch 83/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9373 - loss: 0.1829 - val_accuracy: 0.9396 - val_loss: 0.1716
# Epoch 84/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9361 - loss: 0.1899 - val_accuracy: 0.9432 - val_loss: 0.1718
# Epoch 85/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9387 - loss: 0.1773 - val_accuracy: 0.9423 - val_loss: 0.1704
# Epoch 86/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9399 - loss: 0.1765 - val_accuracy: 0.9414 - val_loss: 0.1716
# Epoch 87/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9395 - loss: 0.1773 - val_accuracy: 0.9405 - val_loss: 0.1721
# Epoch 88/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9396 - loss: 0.1813 - val_accuracy: 0.9414 - val_loss: 0.1712
# Epoch 89/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9403 - loss: 0.1801 - val_accuracy: 0.9418 - val_loss: 0.1719
# Epoch 90/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.1787 - val_accuracy: 0.9423 - val_loss: 0.1704
# Epoch 91/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9405 - loss: 0.1772 - val_accuracy: 0.9423 - val_loss: 0.1700
# Epoch 92/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9411 - loss: 0.1763 - val_accuracy: 0.9418 - val_loss: 0.1710
# Epoch 93/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9429 - loss: 0.1731 - val_accuracy: 0.9414 - val_loss: 0.1718
# Epoch 94/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9414 - loss: 0.1747 - val_accuracy: 0.9405 - val_loss: 0.1728
# Epoch 95/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9399 - loss: 0.1781 - val_accuracy: 0.9423 - val_loss: 0.1706
# Epoch 96/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9390 - loss: 0.1739 - val_accuracy: 0.9427 - val_loss: 0.1703
# Epoch 97/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9372 - loss: 0.1782 - val_accuracy: 0.9414 - val_loss: 0.1689
# Epoch 98/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9371 - loss: 0.1801 - val_accuracy: 0.9414 - val_loss: 0.1690
# Epoch 99/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9386 - loss: 0.1788 - val_accuracy: 0.9427 - val_loss: 0.1682
# Epoch 100/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9423 - loss: 0.1675 - val_accuracy: 0.9432 - val_loss: 0.1696
# Epoch 101/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.1774 - val_accuracy: 0.9405 - val_loss: 0.1695
# Epoch 102/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9451 - loss: 0.1717 - val_accuracy: 0.9414 - val_loss: 0.1683
# Epoch 103/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9407 - loss: 0.1665 - val_accuracy: 0.9418 - val_loss: 0.1679
# Epoch 104/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.1707 - val_accuracy: 0.9423 - val_loss: 0.1693
# Epoch 105/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9379 - loss: 0.1756 - val_accuracy: 0.9423 - val_loss: 0.1696
# Epoch 106/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9415 - loss: 0.1686 - val_accuracy: 0.9423 - val_loss: 0.1673
# Epoch 107/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1719 - val_accuracy: 0.9409 - val_loss: 0.1701
# Epoch 108/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9420 - loss: 0.1684 - val_accuracy: 0.9405 - val_loss: 0.1706
# Epoch 109/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9417 - loss: 0.1645 - val_accuracy: 0.9414 - val_loss: 0.1690
# Epoch 110/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9416 - loss: 0.1679 - val_accuracy: 0.9405 - val_loss: 0.1724
# Epoch 111/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9403 - loss: 0.1685 - val_accuracy: 0.9409 - val_loss: 0.1688
# Epoch 112/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9430 - loss: 0.1742 - val_accuracy: 0.9405 - val_loss: 0.1704
# Epoch 113/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9402 - loss: 0.1697 - val_accuracy: 0.9423 - val_loss: 0.1691
# Epoch 114/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9385 - loss: 0.1718 - val_accuracy: 0.9418 - val_loss: 0.1705
# Epoch 115/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9426 - loss: 0.1656 - val_accuracy: 0.9396 - val_loss: 0.1704
# Epoch 116/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9435 - loss: 0.1676 - val_accuracy: 0.9405 - val_loss: 0.1700
# Epoch 117/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9396 - loss: 0.1642 - val_accuracy: 0.9405 - val_loss: 0.1706
# Epoch 118/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9435 - loss: 0.1661 - val_accuracy: 0.9414 - val_loss: 0.1687
# Epoch 119/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9411 - loss: 0.1658 - val_accuracy: 0.9414 - val_loss: 0.1694
# Epoch 120/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.1614 - val_accuracy: 0.9400 - val_loss: 0.1710
# Epoch 121/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9419 - loss: 0.1649 - val_accuracy: 0.9414 - val_loss: 0.1695
# Epoch 122/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9417 - loss: 0.1661 - val_accuracy: 0.9418 - val_loss: 0.1688
# Epoch 123/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9407 - loss: 0.1723 - val_accuracy: 0.9414 - val_loss: 0.1685
# Epoch 124/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9401 - loss: 0.1663 - val_accuracy: 0.9427 - val_loss: 0.1705
# Epoch 125/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9420 - loss: 0.1702 - val_accuracy: 0.9418 - val_loss: 0.1709
# Epoch 126/10000
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9415 - loss: 0.1686 - val_accuracy: 0.9405 - val_loss: 0.1696

# %%
plot_history(history)

# %% [markdown]
# Dari grafik training loss dan validation loss terlihat bahwa model telah mencapai kondisi konvergen. Selain itu, perbedaan antara training dan validation metrics relatif kecil sehingga tidak terlihat indikasi overfitting yang signifikan.

# %% [markdown]
# ### Model Evaluation

# %%
ann_metrics_df = model_eval(ann_model, X_test_vec, y_test_enc, standard_scaler, sentiment_encoder)
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# Berdasarkan confusion matrix, model mampu memprediksi kelas `negative` dan `positive` dengan cukup baik. Hal ini terlihat dari jumlah prediksi benar yang relatif tinggi pada kedua kelas tersebut.
#
# Namun, performa model pada kelas `neutral` masih cukup rendah. Sebagian besar data berlabel `neutral` diprediksi sebagai `negative`. Hal ini menunjukkan bahwa model mengalami kesulitan dalam membedakan pola fitur antara kelas `neutral` dan `negative`.
#
# Salah satu kemungkinan penyebabnya adalah ketidakseimbangan distribusi data antar kelas, di mana jumlah data neutral jauh lebih sedikit dibandingkan dengan kelas lainnya. Kondisi ini menyebabkan model kurang mampu mempelajari karakteristik dari kelas `neutral`.

# %%
ann_metrics_df
# Out:
#    Accuracy  Precision    Recall  F1 Score
# 0  0.926244   0.920438  0.926244   0.67676

# %% [markdown]
# Meskipun nilai accuracy cukup tinggi, nilai F1-macro relatif lebih rendah. Hal ini menunjukkan bahwa performa model tidak merata pada semua kelas, khususnya pada kelas `neutral` yang memiliki jumlah data lebih sedikit.

# %% [markdown]
# ##  Light Gradient-Boosting Machine

# %% [markdown]
# ### Train Model

# %%
params = {
    "boosting_type": Categorical(["gbdt", "dart"], prior=None),
    "num_leaves": Integer(20, 150),
    "max_depth": Integer(3, 12),
    "learning_rate": Real(0.01, 0.3, prior="log-uniform"),
    "min_child_samples": Integer(5, 100),
    "min_child_weight": Real(1e-3, 10, prior="log-uniform"),
    "subsample": Real(0.5, 1.0, prior="uniform"),
    "colsample_bytree": Real(0.5, 1.0, prior="uniform"),
    "reg_alpha": Real(1e-9, 100.0, prior="log-uniform"),
    "reg_lambda": Real(1e-9, 100.0, prior="log-uniform"),
    "min_split_gain": Real(0.0, 1.0),
    "max_bin": Integer(100, 500)
}

# Inisialisasi Bayesian Search
lgb_model = BayesSearchCV(
    estimator=LGBMClassifier(objective="multiclass", num_class=3, n_jobs=-1, random_state=SEED),
    search_spaces=params,
    cv=5,
    scoring="f1_macro",
    n_iter=100,
    n_jobs=-1,
    verbose=1,
    random_state=SEED,
)
lgb_model.fit(X_train_vec, y_train_enc)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012811 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10000
# [LightGBM] [Info] Number of data points in the train set: 11170, number of used features: 100
# [LightGBM] [Info] Start training from score -0.448219
# [LightGBM] [Info] Start training from score -3.737491
# [LightGBM] [Info] Start training from score -1.086422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# BayesSearchCV(cv=5,
#               estimator=LGBMClassifier(n_jobs=-1, num_class=3,
#                                        objective='multiclass',
#                                        random_state=1010),
#               n_iter=100, n_jobs=-1, random_state=1010, scoring='f1_macro',
#               search_spaces={'boosting_type': Categorical(categories=('gbdt', 'dart'), prior=None),
#                              'colsample_bytree': Real(low=0.5, high=1.0, prior='uniform', transform='normalize'),
#                              'learning_rate': Real(l...
#                              'min_split_gain': Real(low=0.0, high=1.0, prior='uniform', transform='normalize'),
#                              'num_leaves': Integer(low=20, high=150, prior='uniform', transform='normalize'),
#                              'reg_alpha': Real(low=1e-09, high=100.0, prior='log-uniform', transform='normalize'),
#                              'reg_lambda': Real(low=1e-09, high=100.0, prior='log-uniform', transform='normalize'),
#                              'subsample': Real(low=0.5, high=1.0, prior='uniform', transform='normalize')},
#               verbose=1)

# %%
# Menampilkan hyperparameter terbaik dari Bayesian Search
print("Best parameters:", lgb_model.best_params_)
print("Best CV Score:", lgb_model.best_score_)
print("Test Score:", lgb_model.score(X_test_vec, y_test_enc))
# Out:
# Best parameters: OrderedDict({'boosting_type': 'gbdt', 'colsample_bytree': 0.6375450736620186, 'learning_rate': 0.25877784516197666, 'max_bin': 100, 'max_depth': 3, 'min_child_samples': 8, 'min_child_weight': 1.5661192775366242, 'min_split_gain': 0.7561023189889877, 'num_leaves': 46, 'reg_alpha': 3.2626149876340445e-09, 'reg_lambda': 1e-09, 'subsample': 0.6405543299207921})
# Best CV Score: 0.7160822096806195
# Test Score: 0.6417903884873842
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LGBMClassifier was fitted with feature names

# %% [markdown]
# Terlihat adanya indikasi overfitting ringan karena nilai F1-macro pada data validasi cross-validation (71.6%) lebih tinggi dibandingkan performa pada data test (64.2%).

# %% [markdown]
# ### Model Evaluation

# %%
lgb_metrics_df = model_eval(lgb_model, X_test_vec, y_test_enc, standard_scaler, sentiment_encoder)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LGBMClassifier was fitted with feature names

# %% [markdown]
# Berdasarkan confusion matrix, model mampu memprediksi kelas `negative` dan `positive` dengan cukup baik. Hal ini terlihat dari jumlah prediksi benar yang relatif tinggi pada kedua kelas tersebut.
#
# Namun, performa model pada kelas `neutral` masih cukup rendah. Sebagian besar data berlabel `neutral` diprediksi sebagai `negative`. Hal ini menunjukkan bahwa model mengalami kesulitan dalam membedakan pola fitur antara kelas `neutral` dan `negative`.
#
# Salah satu kemungkinan penyebabnya adalah ketidakseimbangan distribusi data antar kelas, di mana jumlah data neutral jauh lebih sedikit dibandingkan dengan kelas lainnya. Kondisi ini menyebabkan model kurang mampu mempelajari karakteristik dari kelas `neutral`.

# %%
lgb_metrics_df
# Out:
#    Accuracy  Precision    Recall  F1 Score
# 0  0.931615   0.921287  0.931615  0.689884

# %% [markdown]
# Model LGBM berhasil mendapatkan 93.2% accuracy, 92.1% Weighted Precision, 93.2% Weighted Recall, dan 69.0% F1-macro pada data test.

# %% [markdown]
# ## Support Vector Machine

# %%
params = {
    "kernel": Categorical(["linear", "poly", "rbf", "sigmoid"], prior=None),
    "gamma": Real(low=1e-3, high=1e3, prior="log-uniform", transform="identity"),
    "C": Real(low=1e-3, high=1e3, prior="log-uniform", transform="identity"),
    "degree": Categorical([2, 3], prior=None)
}

# Inisialisasi Bayesian Search
svc_model = BayesSearchCV(
    estimator=SVC(max_iter=500, random_state=42),
    search_spaces=params,
    cv=5,
    scoring="f1_macro",
    n_iter=100,
    n_jobs=-1,
    verbose=1,
    random_state=SEED,
)
svc_model.fit(X_train_vec, y_train_enc)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning:
#
# Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# BayesSearchCV(cv=5, estimator=SVC(max_iter=500, random_state=42), n_iter=100,
#               n_jobs=-1, random_state=1010, scoring='f1_macro',
#               search_spaces={'C': Real(low=0.001, high=1000.0, prior='log-uniform', transform='normalize'),
#                              'degree': Categorical(categories=(2, 3), prior=None),
#                              'gamma': Real(low=0.001, high=1000.0, prior='log-uniform', transform='normalize'),
#                              'kernel': Categorical(categories=('linear', 'poly', 'rbf', 'sigmoid'), prior=None)},
#               verbose=1)

# %%
# Menampilkan hyperparameter terbaik dari Bayesian Search
print("Best parameters:", svc_model.best_params_)
print("Best CV Score:", svc_model.best_score_)
print("Test Score:", svc_model.score(X_test_vec, y_test_enc))
# Out:
# Best parameters: OrderedDict({'C': 38.77017395035284, 'degree': 2, 'gamma': 0.005421651682068213, 'kernel': 'rbf'})
# Best CV Score: 0.7151374558070226
# Test Score: 0.6564037944470571

# %% [markdown]
# Terindikasi ada cukup overfitting karena Best CV Score 71.5%, sedangkan test score 65.6%.

# %% [markdown]
# ## Model Evaluation

# %%
svc_metrics_df = model_eval(svc_model, X_test_vec, y_test_enc, standard_scaler, sentiment_encoder)

# %% [markdown]
# Berdasarkan confusion matrix, model mampu memprediksi kelas `negative` dan `positive` dengan cukup baik. Hal ini terlihat dari jumlah prediksi benar yang relatif tinggi pada kedua kelas tersebut.
#
# Namun, performa model pada kelas `neutral` masih cukup rendah. Sebagian besar data berlabel `neutral` diprediksi sebagai `negative`. Hal ini menunjukkan bahwa model mengalami kesulitan dalam membedakan pola fitur antara kelas `neutral` dan `negative`.
#
# Salah satu kemungkinan penyebabnya adalah ketidakseimbangan distribusi data antar kelas, di mana jumlah data neutral jauh lebih sedikit dibandingkan dengan kelas lainnya. Kondisi ini menyebabkan model kurang mampu mempelajari karakteristik dari kelas `neutral`.

# %%
svc_metrics_df
# Out:
#    Accuracy  Precision    Recall  F1 Score
# 0  0.919083   0.910057  0.919083  0.705763

# %% [markdown]
# Model SVM berhasil mendapatkan 91.9% accuracy, 91.0% Weighted Precision, 91.9% Weighted Recall, dan 70.6% F1-macro pada data test.

# %% [markdown]
# # Conclusion

# %%
# Menggabungkan metrik evaluasi dari ketiga model
metrics = {
    "ANN": ann_metrics_df,
    "LGBM": lgb_metrics_df,
    "SVC": svc_metrics_df
}

# Menggabungkan dataframe metrik menjadi satu tabel
metrics_df = pd.concat(metrics)
metrics_df.index = metrics_df.index.droplevel(1)
metrics_df.index.name = "Model"
metrics_df
# Out:
#        Accuracy  Precision    Recall  F1 Score
# Model
# ANN    0.926244   0.920438  0.926244  0.676760
# LGBM   0.931615   0.921287  0.931615  0.689884
# SVC    0.919083   0.910057  0.919083  0.705763

# %% [markdown]
# Ketiga model menunjukkan pola kesalahan yang serupa pada confusion matrix, yaitu kesulitan dalam memprediksi kelas `neutral`. Sebagian besar data berlabel `neutral` diprediksi sebagai `negative`. Hal ini mengindikasikan bahwa permasalahan utama kemungkinan berasal dari karakteristik dataset, khususnya ketidakseimbangan distribusi kelas, di mana jumlah data `neutral` jauh lebih sedikit dibandingkan kelas lainnya. Kondisi tersebut menyebabkan model kurang mampu mempelajari pola yang representatif untuk kelas `neutral`. Oleh karena itu, pada tahap pengembangan model selanjutnya dapat dipertimbangkan penerapan teknik penanganan *class imbalance*, seperti *class weighting*, *oversampling*, atau *data augmentation*.
#
# Berdasarkan perbandingan metrik evaluasi, model SVM memiliki nilai **F1-macro tertinggi**, yang menunjukkan kemampuan yang relatif lebih baik dalam menangani distribusi kelas yang tidak seimbang. Namun, dalam proyek ini ditetapkan bahwa model harus mencapai nilai **accuracy minimal sebesar 92%**. Model SVM tidak memenuhi kriteria tersebut karena memiliki nilai accuracy di bawah ambang batas yang ditentukan. Oleh karena itu, **LightGBM dipilih sebagai model terbaik**, karena berhasil memenuhi kriteria accuracy yang ditetapkan sekaligus menunjukkan performa yang kompetitif pada metrik evaluasi lainnya.

# %% [markdown]
# # Save Model Bundle

# %%
# Menyimpan pipeline model yang terdiri dari:
# - Word2Vec embedding
# - StandardScaler
# - LabelEncoder
# - Model klasifikasi LightGBM
joblib.dump({
    "embed_model": embed_model,
    "scaler": standard_scaler,
    "encoder": sentiment_encoder,
    "model": lgb_model
}, "word2vec_lgbm.joblib")
# Out:
# ['word2vec_lgbm.joblib']
